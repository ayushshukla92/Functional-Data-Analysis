# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv('london2007.csv')

# %%
data.describe()
# Out:
#              temp        mean
# count  384.000000  384.000000
# mean    15.377604   11.484375
# std      5.445253    4.825386
# min      4.000000    0.000000
# 25%     11.000000    8.000000
# 50%     15.000000   11.000000
# 75%     20.000000   16.000000
# max     28.000000   21.000000
#
# [8 rows x 2 columns]

# %%
sns.pairplot(data,x_vars=['temp'],y_vars='mean',size=7,aspect=0.7,kind='reg')

# %%
data[['temp','mean']]
# Out:
#     temp  mean
# 0     10     8
# 1     10     7
# 2     12     8
# 3     11     9
# 4     12     8
# 5      9     7
# 6     12     9
# 7     13     9
# 8     14    13
# 9     13     9
# 10    13    10
# 11    13    10
# 12    12    10
# 13    10     7
# 14    11     7
# 15    12    11
# 16    12    10
# 17    14    11
# 18    14    12
# 19    13    10
# 20     8     6
# 21     6     3
# 22     4     1
# 23     5     1
# 24     5     2
# 25     8     2
# 26    10     7
# 27    10     8
# 28    11     9
# 29     8     7
# 30    11     6
# 31    13     9
# 32    12     8
# 33    10     5
# 34     7     2
# 35     5     3
# 36     6     2
# 37     5     0
# 38     4     2
# 39     6     3
# 40    10     8
# 41    11     9
# 42    10     8
# 43     9     7
# 44    10     6
# 45    11     6
# 46    12     9
# 47    11     7
# 48     9     8
# 49    11     9
# 50    11    10
# 51    12    10
# 52    10     9
# 53    12    10
# 54    11     9
# 55    11     8
# 56    10     7
# ...

# %%
from sklearn.cross_validation import KFold

# %%
kf = KFold(25,n_folds=5,shuffle=False)

# %%
print kf
# Out:
# sklearn.cross_validation.KFold(n=25, n_folds=5, shuffle=False, random_state=None)

# %%
# Out:
# /home/ayush/.local/lib/python2.7/site-packages/sklearn/cross_validation.py:79: DeprecationWarning: The indices attribute is deprecated and will be removed (assumed True) in 0.17
#   stacklevel=1)
# True
