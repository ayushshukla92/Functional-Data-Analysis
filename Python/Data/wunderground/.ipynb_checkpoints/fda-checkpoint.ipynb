# %% [markdown]
# ## Classification of Curves

# %% [markdown]
# The following notebook shows the weather curves of different world cities and classify them according to the characterstic of curves.

# %%
# %matplotlib inline
import csv
import numpy as np
import urllib2
import pandas as pd
from subprocess import call
from scipy.interpolate import UnivariateSpline
import matplotlib.pyplot as plt

# %%
stationID = {}
with open('stationID.csv') as csvfile:
    rows = csv.reader(csvfile)
    for row in rows:
        stationID[row[0]] = row[1]

# %%
stationID
# Out:
# {'Boston': 'KBOS',
#  'Chennai': 'VOMM',
#  'Delhi': 'VIDP',
#  'Detroit': 'KDET',
#  'Edmonton': 'CYEG',
#  'Fredericton': 'CYFC',
#  'Halifax': 'CYHZ',
#  'Iqaluit': 'CYFB',
#  'Jaipur': 'VIJP',
#  'Jasper': 'CWJW',
#  'Juneau': 'KUNU',
#  'London': 'CYXU',
#  'Montreal': 'CYUL',
#  'NewYork': 'KLGA',
#  'NiagaraFalls': 'KIAG',
#  'Ottawa': 'CYOW',
#  'Regina': 'CYQR',
#  'Saskatoon': 'CYXE',
#  'Seattle': 'KSEA',
#  'Toronto': 'CYTZ',
#  'Vancouver': 'CYVR',
#  'Victoria': 'CYYJ',
#  'Whitehorse': 'CYXY',
#  'Windsor': 'CYQG',
#  'Winnipeg': 'CYWG',
#  'YellowKnife': 'CYZF'}

# %%
for key in stationID:
    print key
# Out:
# Regina
# Fredericton
# Jaipur
# NewYork
# Whitehorse
# Winnipeg
# Vancouver
# Chennai
# Delhi
# Victoria
# Saskatoon
# Toronto
# Ottawa
# NiagaraFalls
# Detroit
# Montreal
# Iqaluit
# YellowKnife
# Boston
# Edmonton
# London
# Jasper
# Juneau
# Halifax
# Seattle
# Windsor

# %%
initialYear = 2001
endyear = 2003

# %%
from weatherUtils.fda import fda

# %%
X = []
cityMap = {}
k = 0
for key in stationID:
    city = key
    code = stationID[key]
    curStationData = fda(initialYear,endyear,city,code)
    curX = curStationData.getFeatureVector()
    if curX is not None:
        X.append(curX)
        cityMap[k] = city
        k = k+1

# %%
X = pd.DataFrame(X)

# %%
X.shape
# Out:
# (24, 1000)

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA()

# %%
pca.fit(X)
X = pca.transform(X)

# %%
X.shape
# Out:
# (24, 24)

# %%
from sklearn.cluster import KMeans

# %%
est = KMeans(n_clusters=2)

# %%
est.fit(X)
# Out:
# KMeans(copy_x=True, init='k-means++', max_iter=300, n_clusters=2, n_init=10,
#     n_jobs=1, precompute_distances='auto', random_state=None, tol=0.0001,
#     verbose=0)

# %%
labels = est.labels_

# %%
city_class_map = {}
for num,label in enumerate(labels):
    city_class_map[cityMap[num]] = label

# %%
city_class_map
# Out:
# {'Boston': 1,
#  'Delhi': 1,
#  'Detroit': 1,
#  'Edmonton': 0,
#  'Fredericton': 1,
#  'Halifax': 1,
#  'Iqaluit': 0,
#  'Jasper': 0,
#  'Juneau': 1,
#  'London': 1,
#  'Montreal': 1,
#  'NewYork': 1,
#  'NiagaraFalls': 1,
#  'Ottawa': 1,
#  'Regina': 0,
#  'Saskatoon': 0,
#  'Seattle': 1,
#  'Toronto': 1,
#  'Vancouver': 1,
#  'Victoria': 1,
#  'Whitehorse': 0,
#  'Windsor': 1,
#  'Winnipeg': 0,
#  'YellowKnife': 0}

# %%
[city for city in city_class_map if city_class_map[city] == 1]
# Out:
# ['Fredericton',
#  'NewYork',
#  'Vancouver',
#  'Delhi',
#  'Victoria',
#  'Toronto',
#  'Ottawa',
#  'Detroit',
#  'NiagaraFalls',
#  'Montreal',
#  'Boston',
#  'London',
#  'Juneau',
#  'Halifax',
#  'Seattle',
#  'Windsor']
