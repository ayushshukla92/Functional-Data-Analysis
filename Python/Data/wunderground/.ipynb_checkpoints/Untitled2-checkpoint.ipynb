# %%
import pandas as pd

# %%
try:
    data = pd.read_csv("Fredericton2001.csv")
except:
    print "no file exist"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-197840a4273c> in <module>()
#       1 try:
#       2     data = pd.read_csv("Fredericton2001.csv")
# ----> 3 except e:
#       4     print "no file exist"
#
# NameError: name 'e' is not defined

# %%
data
# Out:
#           AST  Max TemperatureC  Mean TemperatureC  Min TemperatureC  \
# 0    2003-1-1                 3                 -2                -8
# 1    2003-1-2                -5                 -8               -11
# 2    2003-1-3                -4                 -9               -13
# 3    2003-1-4                -3                 -7               -11
# 4    2003-1-5                -2                 -8               -13
# 5    2003-1-6                -2                 -7               -12
# 6    2003-1-7                -3                 -4                -5
# 7    2003-1-8                -5                -10               -15
# 8    2003-1-9                -9                -12               -17
# 9   2003-1-10               -10                -16               -21
# 10  2003-1-11               -11                -16               -21
# 11  2003-1-12                -8                -14               -21
# 12  2003-1-13                -5                -11               -16
# ...
